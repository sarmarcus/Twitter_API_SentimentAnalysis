# %% [markdown]
# # <center>1.Authentication</center>

# %%
import tweepy
import time
import datetime
import pandas as pd

#consumer_key="Ev93iW0STr4EymlrqiImSE9yx"
consumer_key = "aHtGWhDgKtBTfohXBe9gMdUgh"

#consumer_secret="xXwORVl6WDjjAIZqhfca4xswBuLs4JQ4EIsWHdfwLay3wdQa5j"
consumer_secret="pSpOjgCvKcoW9ZmLtfrzKk4JpA7604VLlA0N5Thz2CvPEMk344"

#access_token="1037717238525190144-m88Se0GNRFoRb1o00YybdOTXlKCLMG"
access_token="710845973400915968-rexTM2eE79GX0PvX10Ervme2pbMTXFE"

#access_token_secret="u5HI3J7ENvk7oOughDKZQKziBvxIg3NZ0RSSalG2HZMW4"
access_token_secret="9jC9udCr8GAXqLzvA8WAKJG8VvchAVl8HQWziF3oaIRq8"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

print(api.me().name)
# Out:
# Traceback (most recent call last):
#
#   File "/Users/smarcosmila/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2961, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   File "<ipython-input-3-f1c9e7b7346e>", line 1, in <module>
#     import tweepy
#
#   File "/Users/smarcosmila/anaconda3/lib/python3.7/site-packages/tweepy/__init__.py", line 17, in <module>
#     from tweepy.streaming import Stream, StreamListener
#
#   File "/Users/smarcosmila/anaconda3/lib/python3.7/site-packages/tweepy/streaming.py", line 358
#     def _start(self, async):
#                          ^
# SyntaxError: invalid syntax

# %% [markdown]
# # <center>2.Accounts and users information</center>

# %% [markdown]
# # User information

# %%
a = api.me()

# %%
a._json
# Out:
# {'id': 710845973400915968,
#  'id_str': '710845973400915968',
#  'name': 'Chinmay Das',
#  'screen_name': 'chinmaydas96',
#  'location': 'Bhubaneshwar, India',
#  'profile_location': {'id': '404494447ad0eb09',
#   'url': 'https://api.twitter.com/1.1/geo/id/404494447ad0eb09.json',
#   'place_type': 'unknown',
#   'name': 'Bhubaneshwar, India',
#   'full_name': 'Bhubaneshwar, India',
#   'country_code': '',
#   'country': '',
#   'contained_within': [],
#   'bounding_box': None,
#   'attributes': {}},
#  'description': '#python programmer #IOT developer\nMachine Learning and Data science enthusiastic',
#  'url': None,
#  'entities': {'description': {'urls': []}},
#  'protected': False,
#  'followers_count': 40,
#  'friends_count': 298,
#  'listed_count': 5,
#  'created_at': 'Fri Mar 18 15:11:01 +0000 2016',
#  'favourites_count': 37,
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'verified': False,
#  'statuses_count': 10,
#  'lang': 'en',
# ...

# %%
user_info = pd.DataFrame.from_dict(a._json, orient='index')
user_info.reset_index(level=0, inplace=True)
user_info
# Out:
#                                  index  \
# 0                                   id
# 1                               id_str
# 2                                 name
# 3                          screen_name
# 4                             location
# 5                     profile_location
# 6                          description
# 7                                  url
# 8                             entities
# 9                            protected
# 10                     followers_count
# 11                       friends_count
# 12                        listed_count
# 13                          created_at
# 14                    favourites_count
# 15                          utc_offset
# 16                           time_zone
# 17                         geo_enabled
# 18                            verified
# 19                      statuses_count
# 20                                lang
# 21                              status
# 22                contributors_enabled
# ...

# %%
user_name = a._json['screen_name']
user_name
# Out:
# 'chinmaydas96'

# %% [markdown]
# # Following

# %%
f = api.friends()

# %%
following = pd.DataFrame.from_dict(api.friends()[0]._json, orient='index')
following.reset_index(level=0, inplace=True)
following
# Out:
#                                  index  \
# 0                                   id
# 1                               id_str
# 2                                 name
# 3                          screen_name
# 4                             location
# 5                          description
# 6                                  url
# 7                             entities
# 8                            protected
# 9                      followers_count
# 10                       friends_count
# 11                        listed_count
# 12                          created_at
# 13                    favourites_count
# 14                          utc_offset
# 15                           time_zone
# 16                         geo_enabled
# 17                            verified
# 18                      statuses_count
# 19                                lang
# 20                              status
# 21                contributors_enabled
# 22                       is_translator
# ...

# %%
for friend in tweepy.Cursor(api.friends).items():
    # Process the friend here
    #print(friend)
    print(friend._json['screen_name'])
    time.sleep(5)
    print("\n")
# Out:
# keiichiban
#
#
# pathak2206
#
#
# ageitgey
#
#
# beenwrekt
#
#
# GaryMarcus
#
#
# ylecun
#
#
# adampaulcoates
#
#
# AlecRad
#
#
# hugo_larochelle
#
#
# santhukral
#
#
# j2bryson
#
#
# LearnOpenCV
#
#
# petitegeek
#
#
# jjkardwell
#
#
# paulroetzer
#
#
# NathanBenaich
#
#
# nigewillson
#
#
# MFordFuture
#
#
# pabbeel
#
#
# nnaisense
#
#
# fabiomoioli
#
#
# OpenAI
#
#
# iamtrask
#
#
# sirajraval
#
#
# chrmanning
#
#
# seb_ruder
#
#
# dennybritz
#
#
# sravsatuluri
#
#
# JeffDean
#
#
# arthchan2003
#
#
# tim_cook
#
#
# soumithchintala
#
#
# ICPCNews
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-f54821f4cb83> in <module>()
#       3     #print(friend)
#       4     print(friend._json['screen_name'])
# ----> 5     time.sleep(5)
#       6     print("\n")
#
# KeyboardInterrupt:

# %% [markdown]
# # Other user's followers

# %%
#ids = []
#import time
#for page in tweepy.Cursor(api.followers_ids, screen_name="McDonalds").pages():
#    ids.extend(page)
    
#    time.sleep(20)

#print(ids)

# %%
len(api.followers_ids())
# Out:
# 40

# %% [markdown]
# ## Followers

# %%
followers = []
for index, follower in  enumerate(tweepy.Cursor(api.followers).items()):
    followers.append(follower.screen_name)

# %%
followers
# Out:
# ['JyotirmayeeMal8',
#  'Steve_Chance',
#  'Rebecca_dadi',
#  'TensorBeat',
#  'MattAlhonte',
#  'avgiri86',
#  'scoutboundapp',
#  'Lenovodc',
#  'nigewillson',
#  'VedulaRaghu',
#  'JyotirmayeeMal6',
#  'susanmay26',
#  'MsCheikh',
#  'BigData_Fans',
#  'BigData_Hadoop_',
#  '5amStartups',
#  'Memoryhacker007',
#  'sandy_carter',
#  'DeepLearn007',
#  'gSrikarBlog',
#  'ChopDawgStudios',
#  'shipsomecheese',
#  'app_featured',
#  'Abhishek700800',
#  'dl_weekly',
#  'TDataScience',
#  'u2ulearning',
#  'CatchAbhisek',
#  'Subham_30',
#  'Ronald_vanLoon',
#  'sid_e_real',
#  'RaReTechTeam',
#  'Topcoder',
#  'dionnekelley972',
#  'Arcserve',
#  'reddyvamsy',
#  'DavidPomies']

# %% [markdown]
# ## Seach by query

# %%
list_tw = []

# %%
search_results = api.search(q="tensorflow", count=10)

for i in api.search(q="tensorflow", count=10):
    #print(i._json)
    #print('\n\n')
    
    tw = pd.DataFrame.from_dict(i._json, orient='index')
    tw.reset_index(level=0, inplace=True)
    list_tw.append(tw)
    time.sleep(5)

# %%
final_ = pd.concat(list_tw)
final_
# Out:
#                                  index  \
# 0                           created_at
# 1                                   id
# 2                               id_str
# 3                                 text
# 4                            truncated
# 5                             entities
# 6                             metadata
# 7                               source
# 8                in_reply_to_status_id
# 9            in_reply_to_status_id_str
# 10                 in_reply_to_user_id
# 11             in_reply_to_user_id_str
# 12             in_reply_to_screen_name
# 13                                user
# 14                                 geo
# 15                         coordinates
# 16                               place
# 17                        contributors
# 18                     is_quote_status
# 19                       retweet_count
# 20                      favorite_count
# 21                           favorited
# 22                           retweeted
# ...

# %% [markdown]
# # <center>3. Tweets</center>

# %% [markdown]
# ## Total tweets by the user including retweet

# %%
number_of_tweets=200
tweets = api.user_timeline(screen_name=user_name) 

for i in tweets:
    print(i._json['text'])
# Out:
# RT @SebastianThrun: I FLEW THE FIRST FLYING CAR!!!! https://t.co/OjpCSvVeqd via @YouTube
# "Understanding Linear Regression —  Part-2.1" https://t.co/6bk8iOSz79 via @chinmaydas96
# "Monitoring Global warming Linear Regression — Part-2.2" https://t.co/LcFXJJztJK via @chinmaydas96
# I just published “Chopstick Length Analysis” https://t.co/87IghSNQ7v
# I just published “What is machine learning and types of machine learning (Andrew’s machine learning ) — Part-1” https://t.co/Ou4bLsuFEM
# You should have wear that suit Logan .@RealHughJackman
# https://t.co/dali6yClca
# RT @ubuntu: Did you know that #Ubuntu runs in your everyday lives? https://t.co/BvOGMGkJar
# @NovaspiritTech  #SynergyProject #NovaGiveaway
# Trouble in getting my hands around . Synergy is the thing I need . A… https://t.co/itHZ3LidId
# RT @vlasovskikh: Poll for #Python 3.6 Beta enthusiasts. What's your favorite feature? Please RT #PyConJP #MoscowPython
# ...

# %% [markdown]
# ## Retweets the user Tweets

# %%
for tweet in api.user_timeline(screen_name = user_name, count=20):
    for reTweet in api.retweets(tweet.id):
        print("TWEET:", tweet.text)
        print("USER:", reTweet.user.screen_name)
# Out:
# TWEET: You should have wear that suit Logan .@RealHughJackman
# https://t.co/dali6yClca
# USER: pogosdn3nibr
# TWEET: Great talk with @filippovdmitry and @paulweveritt  at #pyconindia .
# @pycharm @jetbrains https://t.co/hy6oyXf2Gs
# USER: filippovdmitry

# %% [markdown]
# ## Likes

# %%
for favorite in tweepy.Cursor(api.favorites, id=user_name).items(20):
    print('\n\n\nTweet Author:')
    # Print the screen name of the tweets auther
    print('Screen Name: '+str(favorite.user.screen_name.encode("utf-8")))
    print('Name: '+str(favorite.user.name.encode("utf-8")))


    #Basic information about the tweet that was favorited
    print('\nTweet:')
    # Print the id of the tweet the user favorited
    print('Tweet Id: '+str(favorite.id))
    # Print the text of the tweet the user favorited
    print('Tweet Text: '+str(favorite.text.encode("utf-8")))
# Out:
# Tweet Author:
# Screen Name: b'AndrewYNg'
# Name: b'Andrew Ng'
#
# Tweet:
# Tweet Id: 1006674256619397120
# Tweet Text: b"Pictures from @Stanford's CS230 (Deep Learning) poster session last Saturday. We grew from 0 to ~800 students in on\xe2\x80\xa6 https://t.co/Gc3uqfyjJ9"
#
#
#
# Tweet Author:
# Screen Name: b'sirajraval'
# Name: b'Siraj Raval'
#
# Tweet:
# Tweet Id: 1006313264282722305
# Tweet Text: b'9 yrs ago in Tokyo a group of old Japanese women asked me to follow them. Curious, I agreed. We took the subway for\xe2\x80\xa6 https://t.co/TulQZhhN0G'
#
#
#
# Tweet Author:
# Screen Name: b'VedulaRaghu'
# Name: b'Raghavendra Vedula'
#
# Tweet:
# Tweet Id: 1005319052812697600
# Tweet Text: b'#io18\n#ioextended\n@gdgbbsr https://t.co/DSZ9U9xQqo'
#
#
#
# Tweet Author:
# Screen Name: b'jeremyphoward'
# Name: b'Jeremy Howard'
#
# Tweet:
# Tweet Id: 981928159879749632
# ...

# %% [markdown]
# ## Own tweet

# %%
api.retweets_of_me()[1]._json
# Out:
# {'created_at': 'Fri Jun 02 04:12:05 +0000 2017',
#  'id': 870493196869967872,
#  'id_str': '870493196869967872',
#  'text': 'I just published “Chopstick Length Analysis” https://t.co/87IghSNQ7v',
#  'truncated': False,
#  'entities': {'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'urls': [{'url': 'https://t.co/87IghSNQ7v',
#     'expanded_url': 'https://medium.com/@chinmaydas96/chopstick-length-analysis-2c4c7e9b6136',
#     'display_url': 'medium.com/@chinmaydas96/…',
#     'indices': [45, 68]}]},
#  'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#  'in_reply_to_status_id': None,
#  'in_reply_to_status_id_str': None,
#  'in_reply_to_user_id': None,
#  'in_reply_to_user_id_str': None,
#  'in_reply_to_screen_name': None,
#  'user': {'id': 710845973400915968,
#   'id_str': '710845973400915968',
#   'name': 'Chinmay Das',
#   'screen_name': 'chinmaydas96',
#   'location': 'Bhubaneshwar, India',
# ...

# %%
tw1 = pd.DataFrame.from_dict(api.retweets_of_me()[1]._json, orient='index')
tw1.reset_index(level=0, inplace=True)

# %%
tw1
# Out:
#                         index  \
# 0                  created_at
# 1                          id
# 2                      id_str
# 3                        text
# 4                   truncated
# 5                    entities
# 6                      source
# 7       in_reply_to_status_id
# 8   in_reply_to_status_id_str
# 9         in_reply_to_user_id
# 10    in_reply_to_user_id_str
# 11    in_reply_to_screen_name
# 12                       user
# 13                        geo
# 14                coordinates
# 15                      place
# 16               contributors
# 17            is_quote_status
# 18              retweet_count
# 19             favorite_count
# 20                  favorited
# 21                  retweeted
# 22         possibly_sensitive
# 23                       lang
#
#                                                     0
# 0                      Fri Jun 02 04:12:05 +0000 2017
# 1                                  870493196869967872
# ...

# %%
for i in api.retweets_of_me():
    print(i._json['text'])
# Out:
# "Understanding Linear Regression —  Part-2.1" https://t.co/6bk8iOSz79 via @chinmaydas96
# I just published “Chopstick Length Analysis” https://t.co/87IghSNQ7v
# I just published “What is machine learning and types of machine learning (Andrew’s machine learning ) — Part-1” https://t.co/Ou4bLsuFEM
# You should have wear that suit Logan .@RealHughJackman
# https://t.co/dali6yClca
# Great talk with @filippovdmitry and @paulweveritt  at #pyconindia .
# @pycharm @jetbrains https://t.co/hy6oyXf2Gs

# %% [markdown]
# # Trending Tweets

# %%
trends1 = api.trends_place(1)

# %%
trends1
# Out:
# [{'trends': [{'name': '#الهلال_الفتح',
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D9%87%D9%84%D8%A7%D9%84_%D8%A7%D9%84%D9%81%D8%AA%D8%AD',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D9%84%D9%87%D9%84%D8%A7%D9%84_%D8%A7%D9%84%D9%81%D8%AA%D8%AD',
#     'tweet_volume': 193255},
#    {'name': '#النصر_التعاون',
#     'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D9%86%D8%B5%D8%B1_%D8%A7%D9%84%D8%AA%D8%B9%D8%A7%D9%88%D9%86',
#     'promoted_content': None,
#     'query': '%23%D8%A7%D9%84%D9%86%D8%B5%D8%B1_%D8%A7%D9%84%D8%AA%D8%B9%D8%A7%D9%88%D9%86',
#     'tweet_volume': 118238},
#    {'name': '#BTSxUnitedNations',
#     'url': 'http://twitter.com/search?q=%23BTSxUnitedNations',
#     'promoted_content': None,
#     'query': '%23BTSxUnitedNations',
#     'tweet_volume': 1200372},
#    {'name': '#BelieveSurvivors',
#     'url': 'http://twitter.com/search?q=%23BelieveSurvivors',
#     'promoted_content': None,
#     'query': '%23BelieveSurvivors',
# ...

# %%
trends1 = api.trends_place(1)
trends = list([trend['name'] for trend in trends1[0]['trends']])
print(trends)
# Out:
# ['#الهلال_الفتح', '#النصر_التعاون', '#BTSxUnitedNations', '#BelieveSurvivors', '#TheBest', 'Rosenstein', 'Modric', 'Mojave', 'Gritty', 'Media Day', 'Amber Guyger', 'Gary Kurtz', 'Kawhi Leonard', 'Michael Kors', 'Puente Pueyrredón', 'Jesse Williams', '#KAIxGUCCI19', '#يعجبك_السهر_اكثر_او_النوم', '#FelizLunes', '#RouanetNão', '#ParoGeneral', '#おそらく最も正確な寿命測定器', '#الاهلي_المحرق', '#24Sep', '#OTDirecto24SEP', '#pantanoso', '#çukurheryerde', '#AskMadison', '#SOSUniversidadesPúblicas', '#نصيحه_الازيمع_لتايه_الراي', '#SiapPakEdy', '#EsDePresumidos', '#GNTMgr', '#MSIgnite', '#VideoShowAoVivo', '#Las17deUnidosPodemos', '#GHVIP24S', '#BuenLunes', '#DaimaŞunuSöylerim', '#FofocalizandoNoSBT', '#MusicMonday', '#walkout', '#dwdd', '#PgssOly', '#VenezuelaSeLevanta', '#1YearWithoutTeenWolf', '#NuevoEstadioLeón', '#TPMPJeu', '#inşaatmühendisleri2000atama', '#TodoASuTiempo']

# %%
trends
# Out:
# ['#الهلال_الفتح',
#  '#النصر_التعاون',
#  '#BTSxUnitedNations',
#  '#BelieveSurvivors',
#  '#TheBest',
#  'Rosenstein',
#  'Modric',
#  'Mojave',
#  'Gritty',
#  'Media Day',
#  'Amber Guyger',
#  'Gary Kurtz',
#  'Kawhi Leonard',
#  'Michael Kors',
#  'Puente Pueyrredón',
#  'Jesse Williams',
#  '#KAIxGUCCI19',
#  '#يعجبك_السهر_اكثر_او_النوم',
#  '#FelizLunes',
#  '#RouanetNão',
#  '#ParoGeneral',
#  '#おそらく最も正確な寿命測定器',
#  '#الاهلي_المحرق',
#  '#24Sep',
#  '#OTDirecto24SEP',
#  '#pantanoso',
#  '#çukurheryerde',
#  '#AskMadison',
#  '#SOSUniversidadesPúblicas',
#  '#نصيحه_الازيمع_لتايه_الراي',
#  '#SiapPakEdy',
#  '#EsDePresumidos',
#  '#GNTMgr',
#  '#MSIgnite',
#  '#VideoShowAoVivo',
#  '#Las17deUnidosPodemos',
#  '#GHVIP24S',
#  '#BuenLunes',
#  '#DaimaŞunuSöylerim',
#  '#FofocalizandoNoSBT',
#  '#MusicMonday',
#  '#walkout',
#  '#dwdd',
#  '#PgssOly',
#  '#VenezuelaSeLevanta',
#  '#1YearWithoutTeenWolf',
#  '#NuevoEstadioLeón',
#  '#TPMPJeu',
#  '#inşaatmühendisleri2000atama',
# ...

# %% [markdown]
# ## Trending hashtag

# %%
trends1 = api.trends_place(1) # from the end of your code
# trends1 is a list with only one element in it, which is a 
# dict which we'll put in data.
data = trends1[0] 
# grab the trends
trends = data['trends']
# grab the name from each trend
names = [trend['name'] for trend in trends]
# put all the names together with a ' ' separating them
trendsName = '\n'.join(names)
print(trendsName)
# Out:
# #الهلال_الفتح
# #النصر_التعاون
# #BTSxUnitedNations
# #BelieveSurvivors
# #TheBest
# Rosenstein
# Modric
# Mojave
# Gritty
# Media Day
# Amber Guyger
# Gary Kurtz
# Kawhi Leonard
# Michael Kors
# Puente Pueyrredón
# Jesse Williams
# #KAIxGUCCI19
# #يعجبك_السهر_اكثر_او_النوم
# #FelizLunes
# #RouanetNão
# #ParoGeneral
# #おそらく最も正確な寿命測定器
# #الاهلي_المحرق
# #24Sep
# #OTDirecto24SEP
# #pantanoso
# #çukurheryerde
# #AskMadison
# #SOSUniversidadesPúblicas
# #نصيحه_الازيمع_لتايه_الراي
# #SiapPakEdy
# #EsDePresumidos
# #GNTMgr
# #MSIgnite
# #VideoShowAoVivo
# #Las17deUnidosPodemos
# #GHVIP24S
# #BuenLunes
# #DaimaŞunuSöylerim
# #FofocalizandoNoSBT
# #MusicMonday
# #walkout
# #dwdd
# #PgssOly
# #VenezuelaSeLevanta
# #1YearWithoutTeenWolf
# #NuevoEstadioLeón
# #TPMPJeu
# #inşaatmühendisleri2000atama
# #TodoASuTiempo

# %% [markdown]
# # Search tweet by hashtag

# %%
trends[0]
# Out:
# {'name': '#الهلال_الفتح',
#  'url': 'http://twitter.com/search?q=%23%D8%A7%D9%84%D9%87%D9%84%D8%A7%D9%84_%D8%A7%D9%84%D9%81%D8%AA%D8%AD',
#  'promoted_content': None,
#  'query': '%23%D8%A7%D9%84%D9%87%D9%84%D8%A7%D9%84_%D8%A7%D9%84%D9%81%D8%AA%D8%AD',
#  'tweet_volume': 193255}

# %%
import json
trends = api.trends_place(1)

search_hashtag = tweepy.Cursor(api.search, q='#SingaporeGP').items(10)

for tweet in search_hashtag:
    print (tweet._json['text'])
    print('********')
# Out:
# RT @MercedesAMGF1: We teamed up with @Bose to explore the significance of getting a good rest to maintaining performance in one of the toug…
# ********
# RT @LuisFeF1: ·8· El nuevo fondo incluía cambios en los extremos del difusor siguiendo las líneas de Red Bull y Ferrari (imagen G. Piola ví…
# ********
# RT @LuisFeF1: ·8· El nuevo fondo incluía cambios en los extremos del difusor siguiendo las líneas de Red Bull y Ferrari (imagen G. Piola ví…
# ********
# ·9· Y para terminar el ya comentado nuevo bargeboard.
# https://t.co/8Y0wcUOOlo
# #TechF1 #F1 #SingaporeGP #TechF12018 #ForceIndia
# ********
# ·8· El nuevo fondo incluía cambios en los extremos del difusor siguiendo las líneas de Red Bull y Ferrari (imagen G… https://t.co/SFXggsH8a0
# ********
# RT @MercedesAMGF1: We teamed up with @Bose to explore the significance of getting a good rest to maintaining performance in one of the toug…
# ********
# ...

# %% [markdown]
# ## Location wise trending

# %%
#api.trends_place("India")

# %%
#results = api.trends_place(_id = 23424975)

# %%
places = api.trends_available()

# %%
places
# Out:
# [{'name': 'Worldwide',
#   'placeType': {'code': 19, 'name': 'Supername'},
#   'url': 'http://where.yahooapis.com/v1/place/1',
#   'parentid': 0,
#   'country': '',
#   'woeid': 1,
#   'countryCode': None},
#  {'name': 'Winnipeg',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/2972',
#   'parentid': 23424775,
#   'country': 'Canada',
#   'woeid': 2972,
#   'countryCode': 'CA'},
#  {'name': 'Ottawa',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3369',
#   'parentid': 23424775,
#   'country': 'Canada',
#   'woeid': 3369,
#   'countryCode': 'CA'},
#  {'name': 'Quebec',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3444',
#   'parentid': 23424775,
#   'country': 'Canada',
#   'woeid': 3444,
#   'countryCode': 'CA'},
#  {'name': 'Montreal',
#   'placeType': {'code': 7, 'name': 'Town'},
#   'url': 'http://where.yahooapis.com/v1/place/3534',
# ...

# %% [markdown]
# ## Location wise Trending

# %%
def get_woeid_usa():
    places = api.trends_available()
    all_woeids = {place['name'].lower(): place['woeid'] for place in places}
    return all_woeids

# %%
def location_to_woeid(location):
    location = location.lower()
    trends = api.trends_available()
    error_string = "This location cannot be resolved to a WOEID"
    all_woeids = get_woeid_usa()
    if location in all_woeids:
        return all_woeids[location]
    else:
        raise ValueError('This location cannot be resolved to a WOEID')

# %%
woeid = location_to_woeid("India")

# %%
api.trends_place(woeid)
# Out:
# [{'trends': [{'name': '#RafaleVadraAngle',
#     'url': 'http://twitter.com/search?q=%23RafaleVadraAngle',
#     'promoted_content': None,
#     'query': '%23RafaleVadraAngle',
#     'tweet_volume': 14126},
#    {'name': '#BTSxUnitedNations',
#     'url': 'http://twitter.com/search?q=%23BTSxUnitedNations',
#     'promoted_content': None,
#     'query': '%23BTSxUnitedNations',
#     'tweet_volume': 1200372},
#    {'name': '#AKkaKaamDekhoShah',
#     'url': 'http://twitter.com/search?q=%23AKkaKaamDekhoShah',
#     'promoted_content': None,
#     'query': '%23AKkaKaamDekhoShah',
#     'tweet_volume': None},
#    {'name': '#मैंने_देखा_है_तुम्हे',
#     'url': 'http://twitter.com/search?q=%23%E0%A4%AE%E0%A5%88%E0%A4%82%E0%A4%A8%E0%A5%87_%E0%A4%A6%E0%A5%87%E0%A4%96%E0%A4%BE_%E0%A4%B9%E0%A5%88_%E0%A4%A4%E0%A5%81%E0%A4%AE%E0%A5%8D%E0%A4%B9%E0%A5%87',
#     'promoted_content': None,
# ...

# %% [markdown]
# # Location Wise Tweets

# %%
places = api.geo_search(query="India", granularity="city")

place_id_L = places[0].id
print('India id is: ',place_id_L)
# Out:
# India id is:  1010ecfa7d3a40f8

# %%
maxitems = 20
print ("India tweets retrieve testing")
print ('----------------------------------')
for tweet in tweepy.Cursor(api.search, q="place:%s" % place_id_L).items(maxitems):
    print (tweet.text)
# Out:
# India tweets retrieve testing
# ----------------------------------
# @josie_woolever Josie! You’re so pretty! ❤️
# I had to remember to unfollow all those Cavaliers media or fan accounts... It’s LAbron Nation now...
# ? Lmao https://t.co/AeCVxBCJhn
# @WNDU Well, a guy got shot and killed at bleachers over stolen chicken wings so...
# @RickyMacias10 @dunkindonuts How’s that ? I’ve never tired te almond milk
# “Damn I lost my nicotine patch” lmao I love college
# I just had to attend a teacher and principal meeting for the first time in my life and if this is what parenting fe… https://t.co/nN3xOTB16E
# @JaneMayerNYer Your name is on it and for me that brings a lot of credibility to the reporting.
# @Mr__PrettyBoy He said he walked from 8 mile
# I wanna go on a date
# I hate feeling confident about material on an exam because that’s when i do my worst.... it makes no sense 🙄
# Any bitch can get took from they nigga that's why iont bother all these hoes friendly
# ...

# %% [markdown]
# # Tweets

# %%
username = "@realDonaldTrump"
tmpTweets = api.user_timeline(username,count=100)

# %%
len(tmpTweets)
# Out:
# 100

# %%
list_df = []

# %%
for i in tmpTweets:
    
    df = pd.DataFrame.from_dict(i._json, orient='index')
    df.reset_index(level=0, inplace=True)
    list_df.append(df)

# %%
pd.concat(list_df,axis=1)
# Out:
#                         index  \
# 0                  created_at
# 1                          id
# 2                      id_str
# 3                        text
# 4                   truncated
# 5                    entities
# 6                      source
# 7       in_reply_to_status_id
# 8   in_reply_to_status_id_str
# 9         in_reply_to_user_id
# 10    in_reply_to_user_id_str
# 11    in_reply_to_screen_name
# 12                       user
# 13                        geo
# 14                coordinates
# 15                      place
# 16               contributors
# 17            is_quote_status
# 18              retweet_count
# 19             favorite_count
# 20                  favorited
# 21                  retweeted
# 22                       lang
# 23                        NaN
# 24                        NaN
# 25                        NaN
# 26                        NaN
#
#                                                     0  \
# ...

# %% [markdown]
# ## Tweets between Specific dates

# %%
username
# Out:
# '@realDonaldTrump'

# %%
import xlsxwriter

# %%
startDate = datetime.datetime(2018, 1, 1, 0, 0, 0)
endDate =   datetime.datetime(2018, 6, 1, 0, 0, 0)

tweets = []
tmpTweets = api.user_timeline(username)
for tweet in tmpTweets:
    if tweet.created_at < endDate and tweet.created_at > startDate:
        tweets.append(tweet)

while (tmpTweets[-1].created_at > startDate):
    #print("Last Tweet @", tmpTweets[-1].created_at, " - fetching some more")
    tmpTweets = api.user_timeline(username, max_id = tmpTweets[-1].id)
    for tweet in tmpTweets:
        if tweet.created_at < endDate and tweet.created_at > startDate:
            tweets.append(tweet)

workbook = xlsxwriter.Workbook(username + ".xlsx")
worksheet = workbook.add_worksheet()
row = 0
for tweet in tweets:
    worksheet.write_string(row, 0, str(tweet.id))
    worksheet.write_string(row, 1, str(tweet.created_at))
    worksheet.write(row, 2, tweet.text)
    worksheet.write_string(row, 3, str(tweet.in_reply_to_status_id))
    row += 1

workbook.close()
print("Excel file ready")
# Out:
# Excel file ready
